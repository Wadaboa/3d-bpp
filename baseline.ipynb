# %%
import os
from collections import namedtuple
from time import time

import numpy as np
import pandas as pd
from ortools.sat.python import cp_model
from matplotlib import pyplot as plt

from src import dataset, config

# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
np.random.seed(config.RANDOM_SEED)

# %%
product_dataset = dataset.ProductDataset(
    "data/products.pkl",
    config.num_products,
    config.pallet_lenght, 
    config.pallet_width, 
    config.max_product_height, 
    config.pallet_load
)
product_dataset.products.head()
# Out:
#    lenght  width  height  weight
# 0     136     79     459      72
# 1     244    365     491      11
# 2      96    410     600       4
# 3     299    119     477      15
# 4     128     20     502      55

# %%
ordered_products = 10
order = product_dataset.get_order(ordered_products)
order.head()
# Out:
#     id  lenght  width  height  weight
# 0  389     225    232     522      49
# 1  565     309     92     210      25
# 2  105      54    131     691      66
# 3  771      65    457     417      42
# 4  821     146    352     753      27

# %% [markdown]
# Pallet EUR:
#
# |       |  $L\times W\times H (cm)$   | Load (kg)  |
# |:-----:|:--------------------------:|:--------:|
# | EUR 1 |  $80\times 120\times 14.5$ |  $2490$  |
# | EUR 2 | $120\times 100\times 14.4$ |  $1470$  |
# | EUR 3 | $100\times 120\times 14.4$ |  $1920$  |
# | EUR 6 |  $80\times 60\times 14.4$  |   $500$  |

# %% [markdown]
# Container ISO:
#
# |   |  $L\times W\times H (cm)$  | Load (kg) |
# |:-:|:--------------------------:|:--------:|
# | 1A | $233\times 1200\times 220$ |  $26480$ |
# | 1C |  $233\times 587\times 220$ |  $28180$ |

# %% [markdown]
# Notes:
# - Mean number of products per order: 75-100
# - Different pallet types in the same order
# - Same container type in the same order
# - Item rotation not allowed

# %%
model = cp_model.CpModel()
max_pallets = ordered_products
Corner = namedtuple("Corner", "x y z")

# Variables
# product_in_pallet[i, j] = 1 if product i is packed in pallet j
product_in_pallet = {}
for i in range(ordered_products):
    for j in range(max_pallets):
        product_in_pallet[(i, j)] = model.NewBoolVar('product_in_pallet_%i_%i' % (i, j))
        
# pallet[i] = 1 if pallet i is used
pallet = {}
for i in range(max_pallets):
    pallet[i] = model.NewBoolVar('pallet_%i' % i)

# blb_corners[i] = [(x_s, x_e), (y_s, y_e), (z_s, z_e)] if product i has blb corner (x_s, y_s, z_s)
blb_corners_start = {}
blb_corners_end = {}
blb_corners_int = {}
for i in range(ordered_products):
    x_s = model.NewIntVar(0, pallet_lenght - int(order.iloc[i].lenght), 'blb_corner_x_start_%i' % i)
    y_s = model.NewIntVar(0, pallet_width - int(order.iloc[i].width), 'blb_corner_y_start_%i' % i)
    z_s = model.NewIntVar(0, max_product_height - int(order.iloc[i].height), 'blb_corner_z_start_%i' % i)
    blb_corners_start[i] = Corner(x_s, y_s, z_s)
    
    x_e = model.NewIntVar(int(order.iloc[i].lenght), pallet_lenght, 'blb_corner_x_end_%i' % i)
    y_e = model.NewIntVar(int(order.iloc[i].width), pallet_width, 'blb_corner_y_end_%i' % i)
    z_e = model.NewIntVar(int(order.iloc[i].height), max_product_height, 'blb_corner_z_end_%i' % i)
    blb_corners_end[i] = Corner(x_e, y_e, z_e)
    
    blb_corners_int[i] = [
        model.NewIntervalVar(x_s, int(order.iloc[i].lenght), x_e, 'blb_corner_x_int_%i' % i),
        model.NewIntervalVar(y_s, int(order.iloc[i].width), y_e, 'blb_corner_y_int_%i' % i),
        model.NewIntervalVar(z_s, int(order.iloc[i].height), z_e, 'blb_corner_z_int_%i' % i)
    ]
    
# prec[i, j, d] = 1 if product i precedes product j on dimension d 
prec = {}
for i in range(ordered_products):
    for j in range(ordered_products):
        if i != j:
            prec[i, j] = [
                model.NewBoolVar('%i_before_%i_x' % (i, j)),
                model.NewBoolVar('%i_before_%i_y' % (i, j)),
                model.NewBoolVar('%i_before_%i_z' % (i, j))
            ]
        
    
# Constraints
# Each product must be in exactly one pallet
for i in range(ordered_products):
    model.Add(sum(product_in_pallet[i, p] for p in range(max_pallets)) == 1)
    
# Precedence constraints
# prec[i, j, d] == 1 if product i precedes product j on dimension d 
#                    and both products are in the same pallet
for p in range(max_pallets):
    for i in range(ordered_products):
        for j in range(ordered_products):
            if i != j:
                model.Add(blb_corners_start[i].x + int(order.iloc[i].lenght) <= blb_corners_start[j].x).OnlyEnforceIf(
                    [prec[i, j][0], product_in_pallet[i, p], product_in_pallet[j, p]]
                )
                model.Add(blb_corners_start[i].x + int(order.iloc[i].lenght) > blb_corners_start[j].x).OnlyEnforceIf(
                    [prec[i, j][0].Not(), product_in_pallet[i, p], product_in_pallet[j, p]]
                )
                model.Add(blb_corners_start[i].y + int(order.iloc[i].width) <= blb_corners_start[j].y).OnlyEnforceIf(
                    [prec[i, j][1], product_in_pallet[i, p], product_in_pallet[j, p]]
                )
                model.Add(blb_corners_start[i].y + int(order.iloc[i].width) > blb_corners_start[j].y).OnlyEnforceIf(
                    [prec[i, j][1].Not(), product_in_pallet[i, p], product_in_pallet[j, p]]
                )
                model.Add(blb_corners_start[i].z + int(order.iloc[i].height) <= blb_corners_start[j].z).OnlyEnforceIf(
                    [prec[i, j][2], product_in_pallet[i, p], product_in_pallet[j, p]]
                )
                model.Add(blb_corners_start[i].z + int(order.iloc[i].height) > blb_corners_start[j].z).OnlyEnforceIf(
                    [prec[i, j][2].Not(), product_in_pallet[i, p], product_in_pallet[j, p]]
                )

# Constraint to ensure that there is at most one spatial relationship 
# between products i and j along each dimension, if they are on the same pallet
for p in range(max_pallets):
    for i in range(ordered_products):
        for j in range(ordered_products):
            if i != j:
                model.Add(prec[i, j][0] + prec[j, i][0] <= 1).OnlyEnforceIf(
                    [product_in_pallet[i, p], product_in_pallet[j, p]]
                )
                model.Add(prec[i, j][1] + prec[j, i][1] <= 1).OnlyEnforceIf(
                    [product_in_pallet[i, p], product_in_pallet[j, p]]
                )
                model.Add(prec[i, j][2] + prec[j, i][2] <= 1).OnlyEnforceIf(
                    [product_in_pallet[i, p], product_in_pallet[j, p]]
                )
                model.Add(prec[i, j][0] + prec[j, i][0] + prec[i, j][1] + prec[j, i][1] + prec[i, j][2] + prec[j, i][2] >= 1).OnlyEnforceIf(
                    [product_in_pallet[i, p], product_in_pallet[j, p]]
                )
    
# Non-overlapping constraint
for p in range(max_pallets):
    for i in range(ordered_products):
        for j in range(ordered_products):
            if i != j:
                model.Add(blb_corners_start[i].x + int(order.iloc[i].lenght) <= blb_corners_start[j].x + pallet_lenght * (1 - prec[i, j][0])).OnlyEnforceIf(
                    [product_in_pallet[i, p], product_in_pallet[j, p]]
                )
                model.Add(blb_corners_start[i].y + int(order.iloc[i].width) <= blb_corners_start[j].y + pallet_width * (1 - prec[i, j][1])).OnlyEnforceIf(
                    [product_in_pallet[i, p], product_in_pallet[j, p]]
                )
                model.Add(blb_corners_start[i].z + int(order.iloc[i].height) <= blb_corners_start[j].z + max_product_height * (1 - prec[i, j][2])).OnlyEnforceIf(
                    [product_in_pallet[i, p], product_in_pallet[j, p]]
                )

# The amount packed in each pallet cannot exceed its liquid volume
for p in range(max_pallets):
    model.Add(
        sum(
            product_in_pallet[i, p] * 
            int(order.iloc[i].lenght) * 
            int(order.iloc[i].width) * 
            int(order.iloc[i].height) 
            for i in range(ordered_products)
        ) <= pallet[p] * pallet_lenght * pallet_width * max_product_height
    )

# The amount packed in each pallet cannot exceed its maximum load
for p in range(max_pallets):
    model.Add(
        sum(
            product_in_pallet[i, p] * 
            int(order.iloc[i].weight) 
            for i in range(ordered_products)
        ) <= pallet[p] * pallet_load
    )

# If at least one product is in a pallet, then that pallet is used
for p in range(max_pallets):
    for i in range(ordered_products):
        model.AddImplication(product_in_pallet[i, p], pallet[p])

"""
for p in range(max_pallets):
    for i in range(ordered_products):
        x_zero = model.NewBoolVar(f"{i}_{p}_cxzero")
        model.Add(blb_corners_start[i].x == 0).OnlyEnforceIf(x_zero)
        y_zero = model.NewBoolVar(f"{i}_{p}_cyzero")
        model.Add(blb_corners_start[i].y == 0).OnlyEnforceIf(y_zero)
        z_zero = model.NewBoolVar(f"{i}_{p}_czzero")
        model.Add(blb_corners_start[i].z == 0).OnlyEnforceIf(z_zero)
        xyz_zero = model.NewBoolVar(f"{i}_{p}_c_xyz_zero")
        model.Add(xyz_zero == 1).OnlyEnforceIf([x_zero, y_zero, z_zero])
        
        corners = [xyz_zero]
        for j in range(ordered_products):
            if i != j:
                x_corner = model.NewBoolVar(f"{i}_{j}_{p}_cxc")
                model.Add(
                    blb_corners_start[i].x == blb_corners_start[j].x + int(order.iloc[j].lenght)
                ).OnlyEnforceIf([x_corner, product_in_pallet[i, p], product_in_pallet[j, p]])
                model.Add(
                    blb_corners_start[i].x != blb_corners_start[j].x + int(order.iloc[j].lenght)
                ).OnlyEnforceIf([x_corner.Not(), product_in_pallet[i, p], product_in_pallet[j, p]])
                
                y_corner = model.NewBoolVar(f"{i}_{j}_{p}_cyc")
                model.Add(
                    blb_corners_start[i].y == blb_corners_start[j].y
                ).OnlyEnforceIf([y_corner, product_in_pallet[i, p], product_in_pallet[j, p]])
                model.Add(
                    blb_corners_start[i].y != blb_corners_start[j].y
                ).OnlyEnforceIf([y_corner.Not(), product_in_pallet[i, p], product_in_pallet[j, p]])
                
                z_corner = model.NewBoolVar(f"{i}_{j}_{p}_czc")
                model.Add(
                    blb_corners_start[i].z == blb_corners_start[j].z
                ).OnlyEnforceIf([z_corner, product_in_pallet[i, p], product_in_pallet[j, p]])
                model.Add(
                    blb_corners_start[i].z != blb_corners_start[j].z
                ).OnlyEnforceIf([z_corner.Not(), product_in_pallet[i, p], product_in_pallet[j, p]])
                
                xyz_corner = model.NewBoolVar(f"{i}_{j}_{p}_cxyzc")
                model.Add(xyz_corner == 1).OnlyEnforceIf([x_corner, y_corner, z_corner])
                model.Add(xyz_corner == 0).OnlyEnforceIf([x_corner.Not(), y_corner, z_corner])
                model.Add(xyz_corner == 0).OnlyEnforceIf([x_corner.Not(), y_corner, z_corner.Not()])
                model.Add(xyz_corner == 0).OnlyEnforceIf([x_corner.Not(), y_corner.Not(), z_corner])
                model.Add(xyz_corner == 0).OnlyEnforceIf([x_corner.Not(), y_corner.Not(), z_corner.Not()])
                model.Add(xyz_corner == 0).OnlyEnforceIf([x_corner, y_corner.Not(), z_corner])
                model.Add(xyz_corner == 0).OnlyEnforceIf([x_corner, y_corner.Not(), z_corner.Not()])
                model.Add(xyz_corner == 0).OnlyEnforceIf([x_corner, y_corner, z_corner.Not()])
                
                corners += [xyz_corner]
        
        model.AddBoolOr(corners)
"""
            
# Search by decreasing volume
volumes = [int(order.iloc[i].lenght) * int(order.iloc[i].width) * int(order.iloc[i].height) for i in range(ordered_products)]
sorted_indexes = np.flip(np.argsort(volumes))
model.AddDecisionStrategy(
    [blb_corners_start[i].z for i in sorted_indexes],
    cp_model.CHOOSE_LOWEST_MIN, cp_model.SELECT_MIN_VALUE
)

# Minimize the number of used pallets
model.Minimize(
    sum(pallet[p] for p in range(max_pallets))
    #sum(pallet[p] * max(blb_corners_start[i].z for i in range(ordered_products)) for p in range(max_pallets))
    #max([blb_corners_start[i].z + int(order.iloc[i].height) for i in range(ordered_products)])
)

# %% [markdown]
# TODO:
# - Search by weight
# - Check non-overlap constraint (min values for blb corners)
# - Products don't fly constraint
#     - Check about corner/extreme points (how to access list of already assigned variables in or-tools?)
# - Time limit
# - Superitems/layers

# %%
solver = cp_model.CpSolver()
solver.parameters.max_time_in_seconds = 120.0
#solver.parameters.search_branching = cp_model.FIXED_SEARCH
start_solve_time = time()
status = solver.Solve(model)
solve_time = time() - start_solve_time
print(f"Number of variables: {model.NumVariables()}")
print(f'Solve status: {solver.StatusName(status)}')
print(f'Solve time: {solve_time}')

if status in (cp_model.OPTIMAL, cp_model.FEASIBLE):
    print(f'Number of pallets: {solver.ObjectiveValue()}')
    print(f'Pallet dimensions: {pallet_lenght}x{pallet_width}x{max_product_height} mm')
    print(f'Pallet maximum load: {pallet_load} kg')
    print(f'Pallet liquid volume: {get_liquid_volume([[pallet_lenght, pallet_width, max_product_height]])} m3')
    print()
    for j in range(max_pallets):
        if solver.Value(pallet[j]):
            pallet_items, pallet_blbs, pallet_weights, pallet_dims = [], [], [], []
            print(f'Pallet #{j}')
            for i in range(ordered_products):
                if solver.Value(product_in_pallet[i, j]) > 0:
                    pallet_items.append(i)
                    pallet_blbs.append((
                        solver.Value(blb_corners_start[i].x),
                        solver.Value(blb_corners_start[i].y),
                        solver.Value(blb_corners_start[i].z)
                    ))
                    pallet_weights.append(order.iloc[i].weight)
                    pallet_dims.append([order.iloc[i].lenght, order.iloc[i].width, order.iloc[i].height])
                    print(f"\tProduct {i}")
                    print(f"\t\tBottom-left-back corner: {pallet_blbs[-1]}")
                    print(f"\t\tDimensions: {pallet_dims[-1][0]}x{pallet_dims[-1][1]}x{pallet_dims[-1][2]} mm")
                    print(f"\t\tWeight: {pallet_weights[-1]} kg")
            
            print(f'Total pallet weight: {sum(pallet_weights)} kg')
            print(f'Total pallet liquid volume: {get_liquid_volume(pallet_dims)} m3') 
            plot_pallet(
                order, 
                pallet_items,
                pallet_blbs, 
                pallet_lenght, 
                pallet_width, 
                max_product_height
            )
            print()
    print(solver.ResponseStats())
elif status == cp_model.MODEL_INVALID:
    print(model.Validate())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-273-d653f8dd46d4> in <module>
#       5 status = solver.Solve(model)
#       6 solve_time = time() - start_solve_time
# ----> 7 print(f"Number of variables: {model.NumVariables()}")
#       8 print(f'Solve status: {solver.StatusName(status)}')
#       9 print(f'Solve time: {solve_time}')
#
# AttributeError: 'CpModel' object has no attribute 'NumVariables'

# %%
[
    (i, j, solver.Value(prec[i, j][0]), solver.Value(prec[i, j][1]), solver.Value(prec[i, j][2]))
    for i in range(ordered_products) for j in range(ordered_products) if i!=j
]
# Out:
# [(0, 1, 1, 1, 0),
#  (0, 2, 1, 1, 0),
#  (0, 3, 0, 1, 1),
#  (0, 4, 0, 1, 1),
#  (0, 5, 0, 1, 1),
#  (0, 6, 0, 1, 1),
#  (0, 7, 0, 1, 0),
#  (0, 8, 1, 0, 0),
#  (0, 9, 0, 1, 0),
#  (0, 10, 1, 0, 0),
#  (0, 11, 1, 0, 0),
#  (0, 12, 1, 1, 1),
#  (0, 13, 0, 1, 0),
#  (0, 14, 1, 1, 0),
#  (0, 15, 0, 0, 0),
#  (0, 16, 1, 1, 0),
#  (0, 17, 1, 1, 0),
#  (0, 18, 0, 1, 0),
#  (0, 19, 1, 0, 0),
#  (1, 0, 0, 0, 0),
#  (1, 2, 0, 0, 0),
#  (1, 3, 0, 0, 1),
#  (1, 4, 0, 0, 1),
#  (1, 5, 0, 0, 1),
#  (1, 6, 0, 0, 1),
#  (1, 7, 0, 1, 0),
#  (1, 8, 0, 0, 0),
#  (1, 9, 0, 0, 0),
#  (1, 10, 0, 0, 0),
#  (1, 11, 0, 0, 0),
#  (1, 12, 0, 0, 1),
#  (1, 13, 0, 0, 0),
#  (1, 14, 0, 0, 0),
#  (1, 15, 0, 0, 0),
#  (1, 16, 0, 0, 0),
#  (1, 17, 0, 0, 0),
#  (1, 18, 0, 0, 0),
#  (1, 19, 0, 0, 0),
#  (2, 0, 0, 0, 1),
#  (2, 1, 0, 0, 1),
#  (2, 3, 0, 0, 1),
#  (2, 4, 0, 0, 1),
#  (2, 5, 0, 0, 1),
#  (2, 6, 0, 0, 1),
#  (2, 7, 0, 1, 1),
#  (2, 8, 0, 0, 1),
#  (2, 9, 0, 0, 1),
#  (2, 10, 0, 0, 1),
#  (2, 11, 0, 0, 1),
#  (2, 12, 0, 0, 1),
#  (2, 13, 0, 0, 0),
#  (2, 14, 0, 0, 0),
#  (2, 15, 0, 0, 1),
#  (2, 16, 0, 0, 1),
#  (2, 17, 0, 0, 0),
#  (2, 18, 0, 0, 1),
#  (2, 19, 0, 0, 0),
#  (3, 0, 0, 0, 0),
#  (3, 1, 1, 0, 0),
#  (3, 2, 1, 0, 0),
#  (3, 4, 0, 0, 1),
#  (3, 5, 0, 0, 0),
#  (3, 6, 0, 0, 0),
#  (3, 7, 0, 1, 0),
#  (3, 8, 1, 0, 0),
#  (3, 9, 0, 0, 0),
#  (3, 10, 1, 0, 0),
#  (3, 11, 1, 0, 0),
#  (3, 12, 1, 0, 1),
#  (3, 13, 0, 0, 0),
#  (3, 14, 1, 0, 0),
#  (3, 15, 0, 0, 0),
#  (3, 16, 1, 0, 0),
#  (3, 17, 1, 0, 0),
#  (3, 18, 0, 0, 0),
#  (3, 19, 1, 0, 0),
#  (4, 0, 0, 0, 0),
#  (4, 1, 1, 0, 0),
#  (4, 2, 1, 0, 0),
#  (4, 3, 0, 0, 0),
#  (4, 5, 0, 0, 0),
#  (4, 6, 0, 0, 0),
#  (4, 7, 0, 1, 0),
#  (4, 8, 1, 0, 0),
#  (4, 9, 0, 0, 0),
#  (4, 10, 1, 0, 0),
#  (4, 11, 1, 0, 0),
#  (4, 12, 1, 0, 0),
#  (4, 13, 0, 0, 0),
#  (4, 14, 1, 0, 0),
#  (4, 15, 0, 0, 0),
#  (4, 16, 1, 0, 0),
#  (4, 17, 1, 0, 0),
#  (4, 18, 0, 0, 0),
#  (4, 19, 1, 0, 0),
#  (5, 0, 0, 0, 0),
#  (5, 1, 1, 0, 0),
#  (5, 2, 1, 0, 0),
#  (5, 3, 0, 0, 1),
#  (5, 4, 0, 0, 1),
#  (5, 6, 0, 0, 0),
#  (5, 7, 0, 1, 0),
#  (5, 8, 1, 0, 0),
#  (5, 9, 0, 0, 0),
#  (5, 10, 1, 0, 0),
#  (5, 11, 1, 0, 0),
#  (5, 12, 1, 0, 1),
#  (5, 13, 0, 0, 0),
#  (5, 14, 1, 0, 0),
#  (5, 15, 0, 0, 0),
#  (5, 16, 1, 0, 0),
#  (5, 17, 1, 0, 0),
#  (5, 18, 0, 0, 0),
#  (5, 19, 1, 0, 0),
#  (6, 0, 0, 0, 0),
#  (6, 1, 1, 0, 0),
#  (6, 2, 1, 0, 0),
#  (6, 3, 0, 0, 1),
#  (6, 4, 0, 0, 1),
#  (6, 5, 0, 0, 1),
#  (6, 7, 0, 1, 0),
#  (6, 8, 1, 0, 0),
#  (6, 9, 0, 0, 0),
#  (6, 10, 1, 0, 0),
#  (6, 11, 1, 0, 0),
#  (6, 12, 1, 0, 1),
#  (6, 13, 0, 0, 0),
#  (6, 14, 1, 0, 0),
#  (6, 15, 0, 0, 0),
#  (6, 16, 1, 0, 0),
#  (6, 17, 1, 0, 0),
#  (6, 18, 0, 0, 0),
#  (6, 19, 1, 0, 0),
#  (7, 0, 0, 0, 0),
#  (7, 1, 1, 0, 0),
#  (7, 2, 1, 0, 0),
#  (7, 3, 0, 0, 1),
#  (7, 4, 0, 0, 1),
#  (7, 5, 0, 0, 1),
#  (7, 6, 0, 0, 1),
#  (7, 8, 1, 0, 0),
#  (7, 9, 0, 0, 0),
#  (7, 10, 1, 0, 0),
#  (7, 11, 1, 0, 0),
#  (7, 12, 1, 0, 1),
#  (7, 13, 0, 0, 0),
#  (7, 14, 1, 0, 0),
#  (7, 15, 0, 0, 0),
#  (7, 16, 1, 0, 0),
#  (7, 17, 1, 0, 0),
#  (7, 18, 0, 0, 0),
#  (7, 19, 1, 0, 0),
#  (8, 0, 0, 0, 0),
#  (8, 1, 0, 1, 0),
#  (8, 2, 0, 1, 0),
#  (8, 3, 0, 1, 1),
#  (8, 4, 0, 1, 1),
#  (8, 5, 0, 1, 1),
#  (8, 6, 0, 1, 1),
#  (8, 7, 0, 1, 0),
#  (8, 9, 0, 1, 0),
#  (8, 10, 0, 0, 0),
#  (8, 11, 0, 0, 0),
#  (8, 12, 0, 1, 1),
#  (8, 13, 0, 1, 0),
#  (8, 14, 0, 1, 0),
#  (8, 15, 0, 0, 0),
#  (8, 16, 0, 1, 0),
#  (8, 17, 0, 1, 0),
#  (8, 18, 0, 1, 0),
#  (8, 19, 0, 0, 0),
#  (9, 0, 0, 0, 0),
#  (9, 1, 1, 0, 0),
#  (9, 2, 1, 0, 0),
#  (9, 3, 0, 0, 1),
#  (9, 4, 0, 0, 1),
#  (9, 5, 0, 0, 1),
#  (9, 6, 0, 0, 1),
#  (9, 7, 0, 1, 0),
#  (9, 8, 1, 0, 0),
#  (9, 10, 1, 0, 0),
#  (9, 11, 1, 0, 0),
#  (9, 12, 1, 0, 1),
#  (9, 13, 0, 0, 0),
#  (9, 14, 1, 0, 0),
#  (9, 15, 0, 0, 0),
#  (9, 16, 1, 0, 0),
#  (9, 17, 1, 0, 0),
#  (9, 18, 0, 0, 0),
#  (9, 19, 1, 0, 0),
#  (10, 0, 0, 0, 1),
#  (10, 1, 1, 1, 1),
#  (10, 2, 1, 1, 0),
#  (10, 3, 0, 1, 1),
#  (10, 4, 0, 1, 1),
#  (10, 5, 0, 1, 1),
#  (10, 6, 0, 1, 1),
#  (10, 7, 0, 1, 1),
#  (10, 8, 1, 0, 1),
#  (10, 9, 0, 1, 1),
#  (10, 11, 1, 0, 0),
#  (10, 12, 1, 1, 1),
#  (10, 13, 0, 1, 0),
#  (10, 14, 0, 1, 0),
#  (10, 15, 0, 0, 0),
#  (10, 16, 1, 1, 0),
#  (10, 17, 0, 1, 0),
#  (10, 18, 0, 1, 0),
#  (10, 19, 1, 0, 0),
#  (11, 0, 0, 0, 1),
#  (11, 1, 0, 1, 1),
#  (11, 2, 0, 1, 0),
#  (11, 3, 0, 1, 1),
#  (11, 4, 0, 1, 1),
#  (11, 5, 0, 1, 1),
#  (11, 6, 0, 1, 1),
#  (11, 7, 0, 1, 1),
#  (11, 8, 0, 0, 1),
#  (11, 9, 0, 1, 1),
#  (11, 10, 0, 0, 1),
#  (11, 12, 0, 1, 1),
#  (11, 13, 0, 1, 0),
#  (11, 14, 0, 1, 0),
#  (11, 15, 0, 0, 0),
#  (11, 16, 0, 1, 0),
#  (11, 17, 0, 1, 0),
#  (11, 18, 0, 1, 0),
#  (11, 19, 0, 0, 0),
#  (12, 0, 0, 0, 0),
#  (12, 1, 0, 0, 0),
#  (12, 2, 0, 0, 0),
#  (12, 3, 0, 0, 0),
#  (12, 4, 0, 0, 0),
#  (12, 5, 0, 0, 0),
#  (12, 6, 0, 0, 0),
#  (12, 7, 0, 1, 0),
#  (12, 8, 0, 0, 0),
#  (12, 9, 0, 0, 0),
#  (12, 10, 0, 0, 0),
#  (12, 11, 0, 0, 0),
#  (12, 13, 0, 0, 0),
#  (12, 14, 0, 0, 0),
#  (12, 15, 0, 0, 0),
#  (12, 16, 0, 0, 0),
#  (12, 17, 0, 0, 0),
#  (12, 18, 0, 0, 0),
#  (12, 19, 0, 0, 0),
#  (13, 0, 0, 0, 1),
#  (13, 1, 1, 0, 1),
#  (13, 2, 1, 0, 0),
#  (13, 3, 0, 0, 1),
#  (13, 4, 0, 0, 1),
#  (13, 5, 0, 0, 1),
#  (13, 6, 0, 0, 1),
#  (13, 7, 0, 1, 1),
#  (13, 8, 1, 0, 1),
#  (13, 9, 0, 0, 1),
#  (13, 10, 1, 0, 1),
#  (13, 11, 1, 0, 1),
#  (13, 12, 1, 0, 1),
#  (13, 14, 1, 0, 0),
#  (13, 15, 0, 0, 1),
#  (13, 16, 1, 0, 1),
#  (13, 17, 1, 0, 0),
#  (13, 18, 0, 0, 1),
#  (13, 19, 1, 0, 0),
#  (14, 0, 0, 0, 1),
#  (14, 1, 1, 0, 1),
#  (14, 2, 1, 0, 0),
#  (14, 3, 0, 0, 1),
#  (14, 4, 0, 0, 1),
#  (14, 5, 0, 0, 1),
#  (14, 6, 0, 0, 1),
#  (14, 7, 0, 1, 1),
#  (14, 8, 1, 0, 1),
#  (14, 9, 0, 0, 1),
#  (14, 10, 0, 0, 1),
#  (14, 11, 1, 0, 1),
#  (14, 12, 1, 0, 1),
#  (14, 13, 0, 0, 0),
#  (14, 15, 0, 0, 1),
#  (14, 16, 1, 0, 1),
#  (14, 17, 0, 0, 0),
#  (14, 18, 0, 0, 1),
#  (14, 19, 1, 0, 0),
#  (15, 0, 0, 0, 1),
#  (15, 1, 1, 1, 1),
#  (15, 2, 1, 1, 0),
#  (15, 3, 0, 1, 1),
#  (15, 4, 0, 1, 1),
#  (15, 5, 0, 1, 1),
#  (15, 6, 0, 1, 1),
#  (15, 7, 0, 1, 1),
#  (15, 8, 1, 0, 1),
#  (15, 9, 0, 1, 1),
#  (15, 10, 1, 0, 1),
#  (15, 11, 1, 0, 0),
#  (15, 12, 1, 1, 1),
#  (15, 13, 0, 1, 0),
#  (15, 14, 1, 1, 0),
#  (15, 16, 1, 1, 0),
#  (15, 17, 1, 1, 0),
#  (15, 18, 0, 1, 0),
#  (15, 19, 1, 0, 0),
#  (16, 0, 0, 0, 1),
#  (16, 1, 0, 0, 1),
#  (16, 2, 0, 0, 0),
#  (16, 3, 0, 0, 1),
#  (16, 4, 0, 0, 1),
#  (16, 5, 0, 0, 1),
#  (16, 6, 0, 0, 1),
#  (16, 7, 0, 1, 1),
#  (16, 8, 0, 0, 1),
#  (16, 9, 0, 0, 1),
#  (16, 10, 0, 0, 1),
#  (16, 11, 0, 0, 0),
#  (16, 12, 0, 0, 1),
#  (16, 13, 0, 0, 0),
#  (16, 14, 0, 0, 0),
#  (16, 15, 0, 0, 0),
#  (16, 17, 0, 0, 0),
#  (16, 18, 0, 0, 0),
#  (16, 19, 0, 0, 0),
#  (17, 0, 0, 0, 1),
#  (17, 1, 1, 0, 1),
#  (17, 2, 1, 0, 0),
#  (17, 3, 0, 0, 1),
#  (17, 4, 0, 0, 1),
#  (17, 5, 0, 0, 1),
#  (17, 6, 0, 0, 1),
#  (17, 7, 0, 1, 1),
#  (17, 8, 1, 0, 1),
#  (17, 9, 0, 0, 1),
#  (17, 10, 1, 0, 1),
#  (17, 11, 1, 0, 1),
#  (17, 12, 1, 0, 1),
#  (17, 13, 0, 0, 0),
#  (17, 14, 1, 0, 0),
#  (17, 15, 0, 0, 1),
#  (17, 16, 1, 0, 1),
#  (17, 18, 0, 0, 1),
#  (17, 19, 1, 0, 0),
#  (18, 0, 0, 0, 1),
#  (18, 1, 1, 0, 1),
#  (18, 2, 1, 0, 0),
#  (18, 3, 0, 0, 1),
#  (18, 4, 0, 0, 1),
#  (18, 5, 0, 0, 1),
#  (18, 6, 0, 0, 1),
#  (18, 7, 0, 1, 1),
#  (18, 8, 1, 0, 1),
#  (18, 9, 0, 0, 1),
#  (18, 10, 1, 0, 1),
#  (18, 11, 1, 0, 0),
#  (18, 12, 1, 0, 1),
#  (18, 13, 0, 0, 0),
#  (18, 14, 1, 0, 0),
#  (18, 15, 0, 0, 0),
#  (18, 16, 1, 0, 0),
#  (18, 17, 1, 0, 0),
#  (18, 19, 1, 0, 0),
#  (19, 0, 0, 0, 1),
#  (19, 1, 0, 1, 1),
#  (19, 2, 0, 1, 0),
#  (19, 3, 0, 1, 1),
#  (19, 4, 0, 1, 1),
#  (19, 5, 0, 1, 1),
#  (19, 6, 0, 1, 1),
#  (19, 7, 0, 1, 1),
#  (19, 8, 0, 0, 1),
#  (19, 9, 0, 1, 1),
#  (19, 10, 0, 0, 1),
#  (19, 11, 0, 0, 1),
#  (19, 12, 0, 1, 1),
#  (19, 13, 0, 1, 0),
#  (19, 14, 0, 1, 0),
#  (19, 15, 0, 0, 1),
#  (19, 16, 0, 1, 1),
#  (19, 17, 0, 1, 0),
#  (19, 18, 0, 1, 1)]

# %%
model._CpModel__model
# Out:
# variables {
#   name: "product_in_pallet_0_0"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_0_1"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_0_2"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_0_3"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_0_4"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_0_5"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_0_6"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_0_7"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_0_8"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_0_9"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_1_0"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_1_1"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_1_2"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_1_3"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_1_4"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_1_5"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_1_6"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_1_7"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_1_8"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_1_9"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_2_0"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_2_1"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_2_2"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_2_3"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_2_4"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_2_5"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_2_6"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_2_7"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_2_8"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_2_9"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_3_0"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_3_1"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_3_2"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_3_3"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_3_4"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_3_5"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_3_6"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_3_7"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_3_8"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_3_9"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_4_0"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_4_1"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_4_2"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_4_3"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_4_4"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_4_5"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_4_6"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_4_7"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_4_8"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_4_9"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_5_0"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_5_1"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_5_2"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_5_3"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_5_4"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_5_5"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_5_6"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_5_7"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_5_8"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_5_9"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_6_0"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_6_1"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_6_2"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_6_3"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_6_4"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_6_5"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_6_6"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_6_7"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_6_8"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_6_9"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_7_0"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_7_1"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_7_2"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_7_3"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_7_4"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_7_5"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_7_6"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_7_7"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_7_8"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_7_9"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_8_0"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_8_1"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_8_2"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_8_3"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_8_4"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_8_5"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_8_6"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_8_7"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_8_8"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_8_9"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_9_0"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_9_1"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_9_2"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_9_3"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_9_4"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_9_5"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_9_6"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_9_7"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_9_8"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "product_in_pallet_9_9"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "pallet_0"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "pallet_1"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "pallet_2"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "pallet_3"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "pallet_4"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "pallet_5"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "pallet_6"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "pallet_7"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "pallet_8"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "pallet_9"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "blb_corner_x_start_0"
#   domain: 0
#   domain: 673
# }
# variables {
#   name: "blb_corner_y_start_0"
#   domain: 0
#   domain: 326
# }
# variables {
#   name: "blb_corner_z_start_0"
#   domain: 0
#   domain: 1507
# }
# variables {
#   name: "blb_corner_x_end_0"
#   domain: 127
#   domain: 800
# }
# variables {
#   name: "blb_corner_y_end_0"
#   domain: 874
#   domain: 1200
# }
# variables {
#   name: "blb_corner_z_end_0"
#   domain: 548
#   domain: 2055
# }
# variables {
#   domain: 127
#   domain: 127
# }
# variables {
#   domain: 874
#   domain: 874
# }
# variables {
#   domain: 548
#   domain: 548
# }
# variables {
#   name: "blb_corner_x_start_1"
#   domain: 0
#   domain: 461
# }
# variables {
#   name: "blb_corner_y_start_1"
#   domain: 0
#   domain: 201
# }
# variables {
#   name: "blb_corner_z_start_1"
#   domain: 0
#   domain: 1173
# }
# variables {
#   name: "blb_corner_x_end_1"
#   domain: 339
#   domain: 800
# }
# variables {
#   name: "blb_corner_y_end_1"
#   domain: 999
#   domain: 1200
# }
# variables {
#   name: "blb_corner_z_end_1"
#   domain: 882
#   domain: 2055
# }
# variables {
#   domain: 339
#   domain: 339
# }
# variables {
#   domain: 999
#   domain: 999
# }
# variables {
#   domain: 882
#   domain: 882
# }
# variables {
#   name: "blb_corner_x_start_2"
#   domain: 0
#   domain: 585
# }
# variables {
#   name: "blb_corner_y_start_2"
#   domain: 0
#   domain: 609
# }
# variables {
#   name: "blb_corner_z_start_2"
#   domain: 0
#   domain: 45
# }
# variables {
#   name: "blb_corner_x_end_2"
#   domain: 215
#   domain: 800
# }
# variables {
#   name: "blb_corner_y_end_2"
#   domain: 591
#   domain: 1200
# }
# variables {
#   name: "blb_corner_z_end_2"
#   domain: 2010
#   domain: 2055
# }
# variables {
#   domain: 215
#   domain: 215
# }
# variables {
#   domain: 591
#   domain: 591
# }
# variables {
#   domain: 2010
#   domain: 2010
# }
# variables {
#   name: "blb_corner_x_start_3"
#   domain: 0
#   domain: 400
# }
# variables {
#   name: "blb_corner_y_start_3"
#   domain: 0
#   domain: 147
# }
# variables {
#   name: "blb_corner_z_start_3"
#   domain: 0
#   domain: 832
# }
# variables {
#   name: "blb_corner_x_end_3"
#   domain: 400
#   domain: 800
# }
# variables {
#   name: "blb_corner_y_end_3"
#   domain: 1053
#   domain: 1200
# }
# variables {
#   name: "blb_corner_z_end_3"
#   domain: 1223
#   domain: 2055
# }
# variables {
#   domain: 400
#   domain: 400
# }
# variables {
#   domain: 1053
#   domain: 1053
# }
# variables {
#   domain: 1223
#   domain: 1223
# }
# variables {
#   name: "blb_corner_x_start_4"
#   domain: 0
#   domain: 184
# }
# variables {
#   name: "blb_corner_y_start_4"
#   domain: 0
#   domain: 1112
# }
# variables {
#   name: "blb_corner_z_start_4"
#   domain: 0
#   domain: 1248
# }
# variables {
#   name: "blb_corner_x_end_4"
#   domain: 616
#   domain: 800
# }
# variables {
#   name: "blb_corner_y_end_4"
#   domain: 88
#   domain: 1200
# }
# variables {
#   name: "blb_corner_z_end_4"
#   domain: 807
#   domain: 2055
# }
# variables {
#   domain: 616
#   domain: 616
# }
# variables {
#   domain: 88
#   domain: 88
# }
# variables {
#   domain: 807
#   domain: 807
# }
# variables {
#   name: "blb_corner_x_start_5"
#   domain: 0
#   domain: 179
# }
# variables {
#   name: "blb_corner_y_start_5"
#   domain: 0
#   domain: 1044
# }
# variables {
#   name: "blb_corner_z_start_5"
#   domain: 0
#   domain: 1802
# }
# variables {
#   name: "blb_corner_x_end_5"
#   domain: 621
#   domain: 800
# }
# variables {
#   name: "blb_corner_y_end_5"
#   domain: 156
#   domain: 1200
# }
# variables {
#   name: "blb_corner_z_end_5"
#   domain: 253
#   domain: 2055
# }
# variables {
#   domain: 621
#   domain: 621
# }
# variables {
#   domain: 156
#   domain: 156
# }
# variables {
#   domain: 253
#   domain: 253
# }
# variables {
#   name: "blb_corner_x_start_6"
#   domain: 0
#   domain: 331
# }
# variables {
#   name: "blb_corner_y_start_6"
#   domain: 0
#   domain: 1141
# }
# variables {
#   name: "blb_corner_z_start_6"
#   domain: 0
#   domain: 1845
# }
# variables {
#   name: "blb_corner_x_end_6"
#   domain: 469
#   domain: 800
# }
# variables {
#   name: "blb_corner_y_end_6"
#   domain: 59
#   domain: 1200
# }
# variables {
#   name: "blb_corner_z_end_6"
#   domain: 210
#   domain: 2055
# }
# variables {
#   domain: 469
#   domain: 469
# }
# variables {
#   domain: 59
#   domain: 59
# }
# variables {
#   domain: 210
#   domain: 210
# }
# variables {
#   name: "blb_corner_x_start_7"
#   domain: 0
#   domain: 697
# }
# variables {
#   name: "blb_corner_y_start_7"
#   domain: 0
#   domain: 138
# }
# variables {
#   name: "blb_corner_z_start_7"
#   domain: 0
#   domain: 1745
# }
# variables {
#   name: "blb_corner_x_end_7"
#   domain: 103
#   domain: 800
# }
# variables {
#   name: "blb_corner_y_end_7"
#   domain: 1062
#   domain: 1200
# }
# variables {
#   name: "blb_corner_z_end_7"
#   domain: 310
#   domain: 2055
# }
# variables {
#   domain: 103
#   domain: 103
# }
# variables {
#   domain: 1062
#   domain: 1062
# }
# variables {
#   domain: 310
#   domain: 310
# }
# variables {
#   name: "blb_corner_x_start_8"
#   domain: 0
#   domain: 385
# }
# variables {
#   name: "blb_corner_y_start_8"
#   domain: 0
#   domain: 1031
# }
# variables {
#   name: "blb_corner_z_start_8"
#   domain: 0
#   domain: 1445
# }
# variables {
#   name: "blb_corner_x_end_8"
#   domain: 415
#   domain: 800
# }
# variables {
#   name: "blb_corner_y_end_8"
#   domain: 169
#   domain: 1200
# }
# variables {
#   name: "blb_corner_z_end_8"
#   domain: 610
#   domain: 2055
# }
# variables {
#   domain: 415
#   domain: 415
# }
# variables {
#   domain: 169
#   domain: 169
# }
# variables {
#   domain: 610
#   domain: 610
# }
# variables {
#   name: "blb_corner_x_start_9"
#   domain: 0
#   domain: 614
# }
# variables {
#   name: "blb_corner_y_start_9"
#   domain: 0
#   domain: 563
# }
# variables {
#   name: "blb_corner_z_start_9"
#   domain: 0
#   domain: 293
# }
# variables {
#   name: "blb_corner_x_end_9"
#   domain: 186
#   domain: 800
# }
# variables {
#   name: "blb_corner_y_end_9"
#   domain: 637
#   domain: 1200
# }
# variables {
#   name: "blb_corner_z_end_9"
#   domain: 1762
#   domain: 2055
# }
# variables {
#   domain: 186
#   domain: 186
# }
# variables {
#   domain: 637
#   domain: 637
# }
# variables {
#   domain: 1762
#   domain: 1762
# }
# variables {
#   name: "0_before_1_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_1_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_1_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_2_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_2_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_2_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_3_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_3_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_3_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_4_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_4_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_4_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_5_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_5_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_5_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_6_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_6_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_6_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_7_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_7_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_7_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_8_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_8_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_8_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_9_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_9_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "0_before_9_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_0_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_0_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_0_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_2_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_2_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_2_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_3_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_3_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_3_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_4_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_4_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_4_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_5_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_5_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_5_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_6_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_6_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_6_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_7_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_7_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_7_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_8_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_8_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_8_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_9_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_9_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "1_before_9_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_0_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_0_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_0_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_1_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_1_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_1_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_3_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_3_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_3_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_4_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_4_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_4_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_5_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_5_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_5_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_6_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_6_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_6_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_7_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_7_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_7_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_8_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_8_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_8_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_9_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_9_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "2_before_9_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_0_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_0_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_0_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_1_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_1_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_1_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_2_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_2_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_2_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_4_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_4_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_4_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_5_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_5_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_5_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_6_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_6_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_6_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_7_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_7_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_7_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_8_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_8_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_8_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_9_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_9_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "3_before_9_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_0_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_0_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_0_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_1_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_1_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_1_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_2_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_2_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_2_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_3_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_3_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_3_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_5_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_5_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_5_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_6_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_6_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_6_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_7_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_7_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_7_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_8_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_8_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_8_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_9_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_9_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "4_before_9_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_0_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_0_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_0_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_1_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_1_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_1_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_2_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_2_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_2_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_3_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_3_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_3_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_4_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_4_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_4_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_6_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_6_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_6_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_7_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_7_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_7_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_8_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_8_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_8_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_9_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_9_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "5_before_9_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_0_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_0_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_0_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_1_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_1_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_1_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_2_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_2_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_2_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_3_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_3_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_3_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_4_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_4_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_4_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_5_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_5_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_5_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_7_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_7_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_7_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_8_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_8_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_8_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_9_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_9_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "6_before_9_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_0_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_0_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_0_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_1_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_1_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_1_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_2_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_2_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_2_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_3_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_3_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_3_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_4_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_4_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_4_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_5_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_5_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_5_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_6_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_6_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_6_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_8_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_8_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_8_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_9_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_9_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "7_before_9_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_0_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_0_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_0_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_1_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_1_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_1_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_2_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_2_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_2_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_3_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_3_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_3_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_4_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_4_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_4_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_5_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_5_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_5_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_6_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_6_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_6_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_7_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_7_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_7_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_9_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_9_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "8_before_9_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_0_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_0_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_0_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_1_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_1_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_1_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_2_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_2_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_2_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_3_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_3_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_3_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_4_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_4_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_4_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_5_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_5_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_5_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_6_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_6_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_6_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_7_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_7_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_7_z"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_8_x"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_8_y"
#   domain: 0
#   domain: 1
# }
# variables {
#   name: "9_before_8_z"
#   domain: 0
#   domain: 1
# }
# constraints {
#   name: "blb_corner_x_int_0"
#   interval {
#     start: 110
#     end: 113
#     size: 116
#   }
# }
# constraints {
#   name: "blb_corner_y_int_0"
#   interval {
#     start: 111
#     end: 114
#     size: 117
#   }
# }
# constraints {
#   name: "blb_corner_z_int_0"
#   interval {
#     start: 112
#     end: 115
#     size: 118
#   }
# }
# constraints {
#   name: "blb_corner_x_int_1"
#   interval {
#     start: 119
#     end: 122
#     size: 125
#   }
# }
# constraints {
#   name: "blb_corner_y_int_1"
#   interval {
#     start: 120
#     end: 123
#     size: 126
#   }
# }
# constraints {
#   name: "blb_corner_z_int_1"
#   interval {
#     start: 121
#     end: 124
#     size: 127
#   }
# }
# constraints {
#   name: "blb_corner_x_int_2"
#   interval {
#     start: 128
#     end: 131
#     size: 134
#   }
# }
# constraints {
#   name: "blb_corner_y_int_2"
#   interval {
#     start: 129
#     end: 132
#     size: 135
#   }
# }
# constraints {
#   name: "blb_corner_z_int_2"
#   interval {
#     start: 130
#     end: 133
#     size: 136
#   }
# }
# constraints {
#   name: "blb_corner_x_int_3"
#   interval {
#     start: 137
#     end: 140
#     size: 143
#   }
# }
# constraints {
#   name: "blb_corner_y_int_3"
#   interval {
#     start: 138
#     end: 141
#     size: 144
#   }
# }
# constraints {
#   name: "blb_corner_z_int_3"
#   interval {
#     start: 139
#     end: 142
#     size: 145
#   }
# }
# constraints {
#   name: "blb_corner_x_int_4"
#   interval {
#     start: 146
#     end: 149
#     size: 152
#   }
# }
# constraints {
#   name: "blb_corner_y_int_4"
#   interval {
#     start: 147
#     end: 150
#     size: 153
#   }
# }
# constraints {
#   name: "blb_corner_z_int_4"
#   interval {
#     start: 148
#     end: 151
#     size: 154
#   }
# }
# constraints {
#   name: "blb_corner_x_int_5"
#   interval {
#     start: 155
#     end: 158
#     size: 161
#   }
# }
# constraints {
#   name: "blb_corner_y_int_5"
#   interval {
#     start: 156
#     end: 159
#     size: 162
#   }
# }
# constraints {
#   name: "blb_corner_z_int_5"
#   interval {
#     start: 157
#     end: 160
#     size: 163
#   }
# }
# constraints {
#   name: "blb_corner_x_int_6"
#   interval {
#     start: 164
#     end: 167
#     size: 170
#   }
# }
# constraints {
#   name: "blb_corner_y_int_6"
#   interval {
#     start: 165
#     end: 168
#     size: 171
#   }
# }
# constraints {
#   name: "blb_corner_z_int_6"
#   interval {
#     start: 166
#     end: 169
#     size: 172
#   }
# }
# constraints {
#   name: "blb_corner_x_int_7"
#   interval {
#     start: 173
#     end: 176
#     size: 179
#   }
# }
# constraints {
#   name: "blb_corner_y_int_7"
#   interval {
#     start: 174
#     end: 177
#     size: 180
#   }
# }
# constraints {
#   name: "blb_corner_z_int_7"
#   interval {
#     start: 175
#     end: 178
#     size: 181
#   }
# }
# constraints {
#   name: "blb_corner_x_int_8"
#   interval {
#     start: 182
#     end: 185
#     size: 188
#   }
# }
# constraints {
#   name: "blb_corner_y_int_8"
#   interval {
#     start: 183
#     end: 186
#     size: 189
#   }
# }
# constraints {
#   name: "blb_corner_z_int_8"
#   interval {
#     start: 184
#     end: 187
#     size: 190
#   }
# }
# constraints {
#   name: "blb_corner_x_int_9"
#   interval {
#     start: 191
#     end: 194
#     size: 197
#   }
# }
# constraints {
#   name: "blb_corner_y_int_9"
#   interval {
#     start: 192
#     end: 195
#     size: 198
#   }
# }
# constraints {
#   name: "blb_corner_z_int_9"
#   interval {
#     start: 193
#     end: 196
#     size: 199
#   }
# }
# constraints {
#   linear {
#     vars: 9
#     vars: 8
#     vars: 7
#     vars: 6
#     vars: 5
#     vars: 4
#     vars: 3
#     vars: 2
#     vars: 1
#     vars: 0
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     domain: 1
#     domain: 1
#   }
# }
# constraints {
#   linear {
#     vars: 19
#     vars: 18
#     vars: 17
#     vars: 16
#     vars: 15
#     vars: 14
#     vars: 13
#     vars: 12
#     vars: 11
#     vars: 10
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     domain: 1
#     domain: 1
#   }
# }
# constraints {
#   linear {
#     vars: 29
#     vars: 28
#     vars: 27
#     vars: 26
#     vars: 25
#     vars: 24
#     vars: 23
#     vars: 22
#     vars: 21
#     vars: 20
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     domain: 1
#     domain: 1
#   }
# }
# constraints {
#   linear {
#     vars: 39
#     vars: 38
#     vars: 37
#     vars: 36
#     vars: 35
#     vars: 34
#     vars: 33
#     vars: 32
#     vars: 31
#     vars: 30
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     domain: 1
#     domain: 1
#   }
# }
# constraints {
#   linear {
#     vars: 49
#     vars: 48
#     vars: 47
#     vars: 46
#     vars: 45
#     vars: 44
#     vars: 43
#     vars: 42
#     vars: 41
#     vars: 40
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     domain: 1
#     domain: 1
#   }
# }
# constraints {
#   linear {
#     vars: 59
#     vars: 58
#     vars: 57
#     vars: 56
#     vars: 55
#     vars: 54
#     vars: 53
#     vars: 52
#     vars: 51
#     vars: 50
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     domain: 1
#     domain: 1
#   }
# }
# constraints {
#   linear {
#     vars: 69
#     vars: 68
#     vars: 67
#     vars: 66
#     vars: 65
#     vars: 64
#     vars: 63
#     vars: 62
#     vars: 61
#     vars: 60
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     domain: 1
#     domain: 1
#   }
# }
# constraints {
#   linear {
#     vars: 79
#     vars: 78
#     vars: 77
#     vars: 76
#     vars: 75
#     vars: 74
#     vars: 73
#     vars: 72
#     vars: 71
#     vars: 70
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     domain: 1
#     domain: 1
#   }
# }
# constraints {
#   linear {
#     vars: 89
#     vars: 88
#     vars: 87
#     vars: 86
#     vars: 85
#     vars: 84
#     vars: 83
#     vars: 82
#     vars: 81
#     vars: 80
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     domain: 1
#     domain: 1
#   }
# }
# constraints {
#   linear {
#     vars: 99
#     vars: 98
#     vars: 97
#     vars: 96
#     vars: 95
#     vars: 94
#     vars: 93
#     vars: 92
#     vars: 91
#     vars: 90
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     coeffs: 1
#     domain: 1
#     domain: 1
#   }
# }
# constraints {
#   enforcement_literal: 200
#   enforcement_literal: 9
#   enforcement_literal: 19
#   linear {
#     vars: 119
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -201
#   enforcement_literal: 9
#   enforcement_literal: 19
#   linear {
#     vars: 119
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 201
#   enforcement_literal: 9
#   enforcement_literal: 19
#   linear {
#     vars: 120
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -202
#   enforcement_literal: 9
#   enforcement_literal: 19
#   linear {
#     vars: 120
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 202
#   enforcement_literal: 9
#   enforcement_literal: 19
#   linear {
#     vars: 121
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -203
#   enforcement_literal: 9
#   enforcement_literal: 19
#   linear {
#     vars: 121
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 203
#   enforcement_literal: 9
#   enforcement_literal: 29
#   linear {
#     vars: 128
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -204
#   enforcement_literal: 9
#   enforcement_literal: 29
#   linear {
#     vars: 128
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 204
#   enforcement_literal: 9
#   enforcement_literal: 29
#   linear {
#     vars: 129
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -205
#   enforcement_literal: 9
#   enforcement_literal: 29
#   linear {
#     vars: 129
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 205
#   enforcement_literal: 9
#   enforcement_literal: 29
#   linear {
#     vars: 130
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -206
#   enforcement_literal: 9
#   enforcement_literal: 29
#   linear {
#     vars: 130
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 206
#   enforcement_literal: 9
#   enforcement_literal: 39
#   linear {
#     vars: 137
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -207
#   enforcement_literal: 9
#   enforcement_literal: 39
#   linear {
#     vars: 137
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 207
#   enforcement_literal: 9
#   enforcement_literal: 39
#   linear {
#     vars: 138
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -208
#   enforcement_literal: 9
#   enforcement_literal: 39
#   linear {
#     vars: 138
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 208
#   enforcement_literal: 9
#   enforcement_literal: 39
#   linear {
#     vars: 139
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -209
#   enforcement_literal: 9
#   enforcement_literal: 39
#   linear {
#     vars: 139
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 209
#   enforcement_literal: 9
#   enforcement_literal: 49
#   linear {
#     vars: 146
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -210
#   enforcement_literal: 9
#   enforcement_literal: 49
#   linear {
#     vars: 146
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 210
#   enforcement_literal: 9
#   enforcement_literal: 49
#   linear {
#     vars: 147
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -211
#   enforcement_literal: 9
#   enforcement_literal: 49
#   linear {
#     vars: 147
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 211
#   enforcement_literal: 9
#   enforcement_literal: 49
#   linear {
#     vars: 148
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -212
#   enforcement_literal: 9
#   enforcement_literal: 49
#   linear {
#     vars: 148
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 212
#   enforcement_literal: 9
#   enforcement_literal: 59
#   linear {
#     vars: 155
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -213
#   enforcement_literal: 9
#   enforcement_literal: 59
#   linear {
#     vars: 155
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 213
#   enforcement_literal: 9
#   enforcement_literal: 59
#   linear {
#     vars: 156
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -214
#   enforcement_literal: 9
#   enforcement_literal: 59
#   linear {
#     vars: 156
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 214
#   enforcement_literal: 9
#   enforcement_literal: 59
#   linear {
#     vars: 157
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -215
#   enforcement_literal: 9
#   enforcement_literal: 59
#   linear {
#     vars: 157
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 215
#   enforcement_literal: 9
#   enforcement_literal: 69
#   linear {
#     vars: 164
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -216
#   enforcement_literal: 9
#   enforcement_literal: 69
#   linear {
#     vars: 164
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 216
#   enforcement_literal: 9
#   enforcement_literal: 69
#   linear {
#     vars: 165
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -217
#   enforcement_literal: 9
#   enforcement_literal: 69
#   linear {
#     vars: 165
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 217
#   enforcement_literal: 9
#   enforcement_literal: 69
#   linear {
#     vars: 166
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -218
#   enforcement_literal: 9
#   enforcement_literal: 69
#   linear {
#     vars: 166
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 218
#   enforcement_literal: 9
#   enforcement_literal: 79
#   linear {
#     vars: 173
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -219
#   enforcement_literal: 9
#   enforcement_literal: 79
#   linear {
#     vars: 173
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 219
#   enforcement_literal: 9
#   enforcement_literal: 79
#   linear {
#     vars: 174
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -220
#   enforcement_literal: 9
#   enforcement_literal: 79
#   linear {
#     vars: 174
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 220
#   enforcement_literal: 9
#   enforcement_literal: 79
#   linear {
#     vars: 175
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -221
#   enforcement_literal: 9
#   enforcement_literal: 79
#   linear {
#     vars: 175
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 221
#   enforcement_literal: 9
#   enforcement_literal: 89
#   linear {
#     vars: 182
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -222
#   enforcement_literal: 9
#   enforcement_literal: 89
#   linear {
#     vars: 182
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 222
#   enforcement_literal: 9
#   enforcement_literal: 89
#   linear {
#     vars: 183
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -223
#   enforcement_literal: 9
#   enforcement_literal: 89
#   linear {
#     vars: 183
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 223
#   enforcement_literal: 9
#   enforcement_literal: 89
#   linear {
#     vars: 184
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -224
#   enforcement_literal: 9
#   enforcement_literal: 89
#   linear {
#     vars: 184
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 224
#   enforcement_literal: 9
#   enforcement_literal: 99
#   linear {
#     vars: 191
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -225
#   enforcement_literal: 9
#   enforcement_literal: 99
#   linear {
#     vars: 191
#     vars: 110
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 225
#   enforcement_literal: 9
#   enforcement_literal: 99
#   linear {
#     vars: 192
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -226
#   enforcement_literal: 9
#   enforcement_literal: 99
#   linear {
#     vars: 192
#     vars: 111
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 226
#   enforcement_literal: 9
#   enforcement_literal: 99
#   linear {
#     vars: 193
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -227
#   enforcement_literal: 9
#   enforcement_literal: 99
#   linear {
#     vars: 193
#     vars: 112
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 227
#   enforcement_literal: 19
#   enforcement_literal: 9
#   linear {
#     vars: 110
#     vars: 119
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: -1
#   }
# }
# constraints {
#   enforcement_literal: -228
#   enforcement_literal: 19
#   enforcement_literal: 9
#   linear {
#     vars: 110
#     vars: 119
#     coeffs: -1
#     coeffs: 1
#     domain: 0
#     domain: 9223372036854775807
#   }
# }
# constraints {
#   enforcement_literal: 228
# ...
# }
# constraints {
#   enforcement_literal: 89
#   enforcement_literal: 59
#   linear {
#     vars: 433
#     vars: 157
#     vars: 184
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 1445
#   }
# }
# constraints {
#   enforcement_literal: 89
#   enforcement_literal: 69
#   linear {
#     vars: 434
#     vars: 164
#     vars: 182
#     coeffs: 800
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 385
#   }
# }
# constraints {
#   enforcement_literal: 89
#   enforcement_literal: 69
#   linear {
#     vars: 435
#     vars: 165
#     vars: 183
#     coeffs: 1200
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 1031
#   }
# }
# constraints {
#   enforcement_literal: 89
#   enforcement_literal: 69
#   linear {
#     vars: 436
#     vars: 166
#     vars: 184
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 1445
#   }
# }
# constraints {
#   enforcement_literal: 89
#   enforcement_literal: 79
#   linear {
#     vars: 437
#     vars: 173
#     vars: 182
#     coeffs: 800
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 385
#   }
# }
# constraints {
#   enforcement_literal: 89
#   enforcement_literal: 79
#   linear {
#     vars: 438
#     vars: 174
#     vars: 183
#     coeffs: 1200
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 1031
#   }
# }
# constraints {
#   enforcement_literal: 89
#   enforcement_literal: 79
#   linear {
#     vars: 439
#     vars: 175
#     vars: 184
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 1445
#   }
# }
# constraints {
#   enforcement_literal: 89
#   enforcement_literal: 99
#   linear {
#     vars: 440
#     vars: 191
#     vars: 182
#     coeffs: 800
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 385
#   }
# }
# constraints {
#   enforcement_literal: 89
#   enforcement_literal: 99
#   linear {
#     vars: 441
#     vars: 192
#     vars: 183
#     coeffs: 1200
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 1031
#   }
# }
# constraints {
#   enforcement_literal: 89
#   enforcement_literal: 99
#   linear {
#     vars: 442
#     vars: 193
#     vars: 184
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 1445
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 9
#   linear {
#     vars: 443
#     vars: 110
#     vars: 191
#     coeffs: 800
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 614
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 9
#   linear {
#     vars: 444
#     vars: 111
#     vars: 192
#     coeffs: 1200
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 563
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 9
#   linear {
#     vars: 445
#     vars: 112
#     vars: 193
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 293
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 19
#   linear {
#     vars: 446
#     vars: 119
#     vars: 191
#     coeffs: 800
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 614
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 19
#   linear {
#     vars: 447
#     vars: 120
#     vars: 192
#     coeffs: 1200
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 563
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 19
#   linear {
#     vars: 448
#     vars: 121
#     vars: 193
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 293
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 29
#   linear {
#     vars: 449
#     vars: 128
#     vars: 191
#     coeffs: 800
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 614
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 29
#   linear {
#     vars: 450
#     vars: 129
#     vars: 192
#     coeffs: 1200
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 563
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 29
#   linear {
#     vars: 451
#     vars: 130
#     vars: 193
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 293
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 39
#   linear {
#     vars: 452
#     vars: 137
#     vars: 191
#     coeffs: 800
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 614
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 39
#   linear {
#     vars: 453
#     vars: 138
#     vars: 192
#     coeffs: 1200
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 563
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 39
#   linear {
#     vars: 454
#     vars: 139
#     vars: 193
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 293
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 49
#   linear {
#     vars: 455
#     vars: 146
#     vars: 191
#     coeffs: 800
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 614
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 49
#   linear {
#     vars: 456
#     vars: 147
#     vars: 192
#     coeffs: 1200
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 563
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 49
#   linear {
#     vars: 457
#     vars: 148
#     vars: 193
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 293
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 59
#   linear {
#     vars: 458
#     vars: 155
#     vars: 191
#     coeffs: 800
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 614
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 59
#   linear {
#     vars: 459
#     vars: 156
#     vars: 192
#     coeffs: 1200
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 563
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 59
#   linear {
#     vars: 460
#     vars: 157
#     vars: 193
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 293
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 69
#   linear {
#     vars: 461
#     vars: 164
#     vars: 191
#     coeffs: 800
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 614
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 69
#   linear {
#     vars: 462
#     vars: 165
#     vars: 192
#     coeffs: 1200
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 563
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 69
#   linear {
#     vars: 463
#     vars: 166
#     vars: 193
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 293
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 79
#   linear {
#     vars: 464
#     vars: 173
#     vars: 191
#     coeffs: 800
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 614
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 79
#   linear {
#     vars: 465
#     vars: 174
#     vars: 192
#     coeffs: 1200
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 563
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 79
#   linear {
#     vars: 466
#     vars: 175
#     vars: 193
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 293
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 89
#   linear {
#     vars: 467
#     vars: 182
#     vars: 191
#     coeffs: 800
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 614
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 89
#   linear {
#     vars: 468
#     vars: 183
#     vars: 192
#     coeffs: 1200
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 563
#   }
# }
# constraints {
#   enforcement_literal: 99
#   enforcement_literal: 89
#   linear {
#     vars: 469
#     vars: 184
#     vars: 193
#     coeffs: 2055
#     coeffs: -1
#     coeffs: 1
#     domain: -9223372036854775808
#     domain: 293
#   }
# }
# constraints {
#   enforcement_literal: 0
#   bool_or {
#     literals: 100
#   }
# }
# constraints {
#   enforcement_literal: 10
#   bool_or {
#     literals: 100
#   }
# }
# constraints {
#   enforcement_literal: 20
#   bool_or {
#     literals: 100
#   }
# }
# constraints {
#   enforcement_literal: 30
#   bool_or {
#     literals: 100
#   }
# }
# constraints {
#   enforcement_literal: 40
#   bool_or {
#     literals: 100
#   }
# }
# constraints {
#   enforcement_literal: 50
#   bool_or {
#     literals: 100
#   }
# }
# constraints {
#   enforcement_literal: 60
#   bool_or {
#     literals: 100
#   }
# }
# constraints {
#   enforcement_literal: 70
#   bool_or {
#     literals: 100
#   }
# }
# constraints {
#   enforcement_literal: 80
#   bool_or {
#     literals: 100
#   }
# }
# constraints {
#   enforcement_literal: 90
#   bool_or {
#     literals: 100
#   }
# }
# constraints {
#   enforcement_literal: 1
#   bool_or {
#     literals: 101
#   }
# }
# constraints {
#   enforcement_literal: 11
#   bool_or {
#     literals: 101
#   }
# }
# constraints {
#   enforcement_literal: 21
#   bool_or {
#     literals: 101
#   }
# }
# constraints {
#   enforcement_literal: 31
#   bool_or {
#     literals: 101
#   }
# }
# constraints {
#   enforcement_literal: 41
#   bool_or {
#     literals: 101
#   }
# }
# constraints {
#   enforcement_literal: 51
#   bool_or {
#     literals: 101
#   }
# }
# constraints {
#   enforcement_literal: 61
#   bool_or {
#     literals: 101
#   }
# }
# constraints {
#   enforcement_literal: 71
#   bool_or {
#     literals: 101
#   }
# }
# constraints {
#   enforcement_literal: 81
#   bool_or {
#     literals: 101
#   }
# }
# constraints {
#   enforcement_literal: 91
#   bool_or {
#     literals: 101
#   }
# }
# constraints {
#   enforcement_literal: 2
#   bool_or {
#     literals: 102
#   }
# }
# constraints {
#   enforcement_literal: 12
#   bool_or {
#     literals: 102
#   }
# }
# constraints {
#   enforcement_literal: 22
#   bool_or {
#     literals: 102
#   }
# }
# constraints {
#   enforcement_literal: 32
#   bool_or {
#     literals: 102
#   }
# }
# constraints {
#   enforcement_literal: 42
#   bool_or {
#     literals: 102
#   }
# }
# constraints {
#   enforcement_literal: 52
#   bool_or {
#     literals: 102
#   }
# }
# constraints {
#   enforcement_literal: 62
#   bool_or {
#     literals: 102
#   }
# }
# constraints {
#   enforcement_literal: 72
#   bool_or {
#     literals: 102
#   }
# }
# constraints {
#   enforcement_literal: 82
#   bool_or {
#     literals: 102
#   }
# }
# constraints {
#   enforcement_literal: 92
#   bool_or {
#     literals: 102
#   }
# }
# constraints {
#   enforcement_literal: 3
#   bool_or {
#     literals: 103
#   }
# }
# constraints {
#   enforcement_literal: 13
#   bool_or {
#     literals: 103
#   }
# }
# constraints {
#   enforcement_literal: 23
#   bool_or {
#     literals: 103
#   }
# }
# constraints {
#   enforcement_literal: 33
#   bool_or {
#     literals: 103
#   }
# }
# constraints {
#   enforcement_literal: 43
#   bool_or {
#     literals: 103
#   }
# }
# constraints {
#   enforcement_literal: 53
#   bool_or {
#     literals: 103
#   }
# }
# constraints {
#   enforcement_literal: 63
#   bool_or {
#     literals: 103
#   }
# }
# constraints {
#   enforcement_literal: 73
#   bool_or {
#     literals: 103
#   }
# }
# constraints {
#   enforcement_literal: 83
#   bool_or {
#     literals: 103
#   }
# }
# constraints {
#   enforcement_literal: 93
#   bool_or {
#     literals: 103
#   }
# }
# constraints {
#   enforcement_literal: 4
#   bool_or {
#     literals: 104
#   }
# }
# constraints {
#   enforcement_literal: 14
#   bool_or {
#     literals: 104
#   }
# }
# constraints {
#   enforcement_literal: 24
#   bool_or {
#     literals: 104
#   }
# }
# constraints {
#   enforcement_literal: 34
#   bool_or {
#     literals: 104
#   }
# }
# constraints {
#   enforcement_literal: 44
#   bool_or {
#     literals: 104
#   }
# }
# constraints {
#   enforcement_literal: 54
#   bool_or {
#     literals: 104
#   }
# }
# constraints {
#   enforcement_literal: 64
#   bool_or {
#     literals: 104
#   }
# }
# constraints {
#   enforcement_literal: 74
#   bool_or {
#     literals: 104
#   }
# }
# constraints {
#   enforcement_literal: 84
#   bool_or {
#     literals: 104
#   }
# }
# constraints {
#   enforcement_literal: 94
#   bool_or {
#     literals: 104
#   }
# }
# constraints {
#   enforcement_literal: 5
#   bool_or {
#     literals: 105
#   }
# }
# constraints {
#   enforcement_literal: 15
#   bool_or {
#     literals: 105
#   }
# }
# constraints {
#   enforcement_literal: 25
#   bool_or {
#     literals: 105
#   }
# }
# constraints {
#   enforcement_literal: 35
#   bool_or {
#     literals: 105
#   }
# }
# constraints {
#   enforcement_literal: 45
#   bool_or {
#     literals: 105
#   }
# }
# constraints {
#   enforcement_literal: 55
#   bool_or {
#     literals: 105
#   }
# }
# constraints {
#   enforcement_literal: 65
#   bool_or {
#     literals: 105
#   }
# }
# constraints {
#   enforcement_literal: 75
#   bool_or {
#     literals: 105
#   }
# }
# constraints {
#   enforcement_literal: 85
#   bool_or {
#     literals: 105
#   }
# }
# constraints {
#   enforcement_literal: 95
#   bool_or {
#     literals: 105
#   }
# }
# constraints {
#   enforcement_literal: 6
#   bool_or {
#     literals: 106
#   }
# }
# constraints {
#   enforcement_literal: 16
#   bool_or {
#     literals: 106
#   }
# }
# constraints {
#   enforcement_literal: 26
#   bool_or {
#     literals: 106
#   }
# }
# constraints {
#   enforcement_literal: 36
#   bool_or {
#     literals: 106
#   }
# }
# constraints {
#   enforcement_literal: 46
#   bool_or {
#     literals: 106
#   }
# }
# constraints {
#   enforcement_literal: 56
#   bool_or {
#     literals: 106
#   }
# }
# constraints {
#   enforcement_literal: 66
#   bool_or {
#     literals: 106
#   }
# }
# constraints {
#   enforcement_literal: 76
#   bool_or {
#     literals: 106
#   }
# }
# constraints {
#   enforcement_literal: 86
#   bool_or {
#     literals: 106
#   }
# }
# constraints {
#   enforcement_literal: 96
#   bool_or {
#     literals: 106
#   }
# }
# constraints {
#   enforcement_literal: 7
#   bool_or {
#     literals: 107
#   }
# }
# constraints {
#   enforcement_literal: 17
#   bool_or {
#     literals: 107
#   }
# }
# constraints {
#   enforcement_literal: 27
#   bool_or {
#     literals: 107
#   }
# }
# constraints {
#   enforcement_literal: 37
#   bool_or {
#     literals: 107
#   }
# }
# constraints {
#   enforcement_literal: 47
#   bool_or {
#     literals: 107
#   }
# }
# constraints {
#   enforcement_literal: 57
#   bool_or {
#     literals: 107
#   }
# }
# constraints {
#   enforcement_literal: 67
#   bool_or {
#     literals: 107
#   }
# }
# constraints {
#   enforcement_literal: 77
#   bool_or {
#     literals: 107
#   }
# }
# constraints {
#   enforcement_literal: 87
#   bool_or {
#     literals: 107
#   }
# }
# constraints {
#   enforcement_literal: 97
#   bool_or {
#     literals: 107
#   }
# }
# constraints {
#   enforcement_literal: 8
#   bool_or {
#     literals: 108
#   }
# }
# constraints {
#   enforcement_literal: 18
#   bool_or {
#     literals: 108
#   }
# }
# constraints {
#   enforcement_literal: 28
#   bool_or {
#     literals: 108
#   }
# }
# constraints {
#   enforcement_literal: 38
#   bool_or {
#     literals: 108
#   }
# }
# constraints {
#   enforcement_literal: 48
#   bool_or {
#     literals: 108
#   }
# }
# constraints {
#   enforcement_literal: 58
#   bool_or {
#     literals: 108
#   }
# }
# constraints {
#   enforcement_literal: 68
#   bool_or {
#     literals: 108
#   }
# }
# constraints {
#   enforcement_literal: 78
#   bool_or {
#     literals: 108
#   }
# }
# constraints {
#   enforcement_literal: 88
#   bool_or {
#     literals: 108
#   }
# }
# constraints {
#   enforcement_literal: 98
#   bool_or {
#     literals: 108
#   }
# }
# constraints {
#   enforcement_literal: 9
#   bool_or {
#     literals: 109
#   }
# }
# constraints {
#   enforcement_literal: 19
#   bool_or {
#     literals: 109
#   }
# }
# constraints {
#   enforcement_literal: 29
#   bool_or {
#     literals: 109
#   }
# }
# constraints {
#   enforcement_literal: 39
#   bool_or {
#     literals: 109
#   }
# }
# constraints {
#   enforcement_literal: 49
#   bool_or {
#     literals: 109
#   }
# }
# constraints {
#   enforcement_literal: 59
#   bool_or {
#     literals: 109
#   }
# }
# constraints {
#   enforcement_literal: 69
#   bool_or {
#     literals: 109
#   }
# }
# constraints {
#   enforcement_literal: 79
#   bool_or {
#     literals: 109
#   }
# }
# constraints {
#   enforcement_literal: 89
#   bool_or {
#     literals: 109
#   }
# }
# constraints {
#   enforcement_literal: 99
#   bool_or {
#     literals: 109
#   }
# }
# objective {
#   vars: 109
#   vars: 108
#   vars: 107
#   vars: 106
#   vars: 105
#   vars: 104
#   vars: 103
#   vars: 102
#   vars: 101
#   vars: 100
#   scaling_factor: 1.0
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
#   coeffs: 1
# }
